# %%
import numpy as np
import cv2
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
import glob

images = glob.glob('/home/gokul/CarND-Advanced-Lane-Lines-master/camera_cal/calibration*.jpg')

objpoints = []
imgpoints = []

objp = np.zeros((5*8, 3), np.float32)
objp[:,:2] = np.mgrid[0:8,0:5].T.reshape(-1,2)
fname = '/home/gokul/CarND-Advanced-Lane-Lines-master/camera_cal/calibration4.jpg'
image = cv2.imread(fname)
plt.imshow(image)
plt.show()
gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
ret, corners = cv2.findChessboardCorners(gray, (8,5), None)
if ret == True:
    cv2.drawChessboardCorners(image, (8,5), corners, ret)
    plt.imshow(image)
    plt.show()
